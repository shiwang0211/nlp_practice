# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import matplotlib as plt
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename

# %%
filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
vocabulary[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
vocabulary_size = 50000
def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)

# %%
data[:10]
# Out:
# [5240, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
dictionary
# Out:
# {'rear': 4027,
#  'grapple': 36748,
#  'sichuan': 27350,
#  'encircles': 44612,
#  'natively': 19751,
#  'valves': 9552,
#  'scharnhorst': 30323,
#  'tastes': 10477,
#  'foreman': 22701,
#  'kingston': 10713,
#  'pannonia': 22515,
#  'problems': 640,
#  'groundbreaking': 16023,
#  'convention': 1186,
#  'unending': 46467,
#  'onboard': 18395,
#  'guerrilla': 5715,
#  'sidewise': 46283,
#  'zealand': 1637,
#  'vers': 37838,
#  'cochran': 33801,
#  'szczecin': 49334,
#  'vorkosigan': 48602,
#  'ign': 41018,
#  'insular': 13675,
#  'vivekananda': 45234,
#  'convoy': 17567,
#  'lantau': 31660,
#  'khanate': 27040,
#  'lamp': 8322,
#  'theosis': 45851,
#  'cavaliers': 40562,
#  'heroine': 19101,
#  'laval': 25637,
#  'lodging': 23737,
#  'sharpe': 29191,
#  'harpoon': 24046,
#  'canisters': 47603,
#  'sugarcane': 17627,
#  'thucydides': 24173,
#  'unhappy': 12177,
#  'cruz': 9226,
#  'jockeys': 27625,
#  'enable': 6973,
#  'araki': 43003,
#  'homeopaths': 29192,
#  'direct': 873,
#  'quantities': 3883,
#  'linden': 34346,
#  'cessation': 17996,
#  'abdomen': 14710,
#  'degeneration': 23099,
#  'ethnocentric': 39752,
#  'octahedra': 38172,
#  'spectroscopic': 24860,
#  'day': 137,
#  'pron': 25505,
#  'lansdowne': 45858,
#  'roxy': 25765,
#  'wmap': 29019,
#  'mobilized': 27041,
#  'patched': 36749,
#  'ineffectiveness': 48136,
#  'heavy': 1007,
#  'raimi': 22808,
#  'locator': 27115,
#  'gypsys': 45236,
#  'wipo': 12526,
#  'ward': 5132,
#  'perihelion': 20644,
#  'aryan': 7707,
#  'classics': 6006,
#  'crude': 7002,
#  'sca': 37431,
#  'removed': 1633,
#  'gateway': 7224,
#  'botched': 31893,
#  'bidding': 16073,
#  'futurology': 44613,
#  'wrote': 557,
#  'julia': 5698,
#  'metabolism': 7227,
#  'bases': 3284,
#  'brin': 32815,
#  'hesitated': 40179,
#  'ebu': 16872,
#  'elbridge': 46724,
#  'sheen': 21974,
#  'gomorrah': 34347,
#  'signatures': 10818,
#  'zambia': 11065,
#  'nessie': 20300,
#  'che': 10181,
#  'theocracy': 31655,
#  'modulated': 20228,
#  'seam': 30187,
#  'night': 807,
#  'regardless': 3265,
#  'navigators': 24624,
#  'maximizing': 24174,
#  'irregulars': 27043,
#  'numerology': 28630,
#  'galleria': 22809,
#  'shipyard': 23432,
#  'graceful': 26186,
#  'arguing': 5150,
#  'commissioner': 5721,
#  'avalokitesvara': 42383,
#  'antigens': 19093,
#  'traffic': 2035,
#  'crops': 4176,
#  'toronto': 4031,
#  'robbers': 25638,
#  'emigration': 9541,
#  'mourning': 13513,
#  'correspond': 5889,
#  'kingship': 19102,
#  'tutorial': 9987,
#  'apparent': 2488,
#  'encke': 49449,
#  'lurker': 48603,
#  'bef': 41882,
#  'ionizing': 22703,
#  'weld': 26753,
#  'climb': 9893,
#  'dearly': 36412,
#  'helsing': 21554,
#  'authorities': 2230,
#  'nonviolent': 20926,
#  'carpenter': 10785,
#  'eighty': 8312,
#  'parachute': 13903,
#  'faber': 14411,
#  'atc': 21544,
#  'expending': 47135,
#  'monad': 27626,
#  'exquisite': 31438,
#  'parse': 29640,
#  'righteous': 10890,
#  'gediminas': 42433,
#  'conveyor': 31439,
#  'undisputed': 18896,
#  'flavoring': 34651,
#  'tavern': 16838,
#  'geological': 5687,
#  'counselor': 28264,
#  'specimens': 11427,
#  'untso': 48789,
#  'gico': 45238,
#  'morphemes': 16189,
#  'silly': 15814,
#  'timaeus': 34082,
#  'alexandrians': 49046,
#  'manipulates': 32816,
#  'guillotine': 28352,
#  'lr': 14375,
#  'untreated': 20651,
#  'wolfram': 20162,
#  'interstate': 6007,
#  'beacon': 15068,
#  'bbb': 28631,
#  'calista': 30753,
#  'algebraically': 17681,
#  'kaos': 39321,
#  'counterfeiting': 46903,
#  'breda': 37432,
#  'plantation': 11200,
#  'unlike': 1321,
#  'leagues': 5339,
#  'modifies': 26321,
#  'filenames': 38561,
#  'publish': 5597,
#  'chromosomes': 5926,
#  'lively': 13765,
#  'klondike': 34083,
#  'schemes': 6632,
#  'motionless': 35212,
#  'apse': 46359,
#  'bedi': 30107,
#  'plateau': 4765,
#  'informed': 5734,
#  'mostly': 758,
#  'khagan': 29193,
#  'sacerdotal': 45853,
#  'grozny': 27959,
#  'rtf': 42434,
#  'excitation': 24864,
#  'deficits': 13462,
#  'molson': 47136,
#  'providers': 6467,
#  'cleanliness': 26898,
#  'pontchartrain': 44614,
#  'suggestion': 7242,
#  'saeima': 36076,
#  'bahri': 43052,
#  'neuro': 36413,
#  'outlying': 14186,
#  'deanna': 42984,
#  'ample': 17808,
#  'boutiques': 49465,
#  'nudes': 49336,
#  'ludicrous': 31616,
#  'corporatist': 33313,
#  'intercontinental': 18712,
#  'bcg': 44615,
#  'dulles': 24283,
#  'circassians': 44043,
#  'particular': 480,
#  'stimulated': 11093,
#  'inge': 34948,
#  'awk': 16728,
#  'influencing': 13121,
#  'cabot': 12905,
#  'soroban': 41735,
#  'microbial': 18861,
#  'metre': 6593,
#  'surgeons': 18036,
#  'councilors': 38935,
#  'cartilaginous': 39322,
#  'cumann': 38174,
#  'nic': 21975,
#  'peake': 23956,
#  'hardwired': 40440,
#  'convergent': 14587,
#  'elegance': 24743,
#  'lombardo': 46798,
#  'angora': 33066,
#  'gamsakhurdia': 41962,
#  'swift': 8226,
#  'citeaux': 47399,
#  'versus': 3996,
#  'horch': 27632,
#  'copyleft': 8995,
#  'tongues': 13293,
#  'dst': 22893,
#  'disallow': 36414,
#  'mace': 18155,
#  'novelist': 4348,
#  'provincial': 4347,
#  'rocky': 5645,
#  'grapevine': 38563,
#  'unspoiled': 36751,
#  'patchy': 38175,
#  'hideo': 49338,
#  'ranges': 3621,
#  'means': 363,
#  'madonna': 11605,
#  'ahl': 43532,
#  'macau': 4530,
#  'ties': 3881,
#  'manna': 33564,
#  'ordinances': 12621,
#  'jabbar': 22075,
#  'consecutively': 30108,
#  'disparaged': 41020,
#  'insubordination': 40180,
#  'honolulu': 9358,
#  'acetyl': 23645,
#  'informative': 16730,
#  'meyer': 11969,
#  'archaeologists': 10872,
#  'hovercraft': 35792,
#  'lindsey': 25890,
#  'fistula': 49717,
#  'sprite': 19908,
#  'disambiguation': 3492,
#  'continental': 2215,
#  'filaments': 24145,
#  'flurry': 27351,
#  'undecidable': 18441,
#  'shoddy': 45239,
#  'synthetic': 5453,
#  'biologist': 9582,
#  'volumes': 3639,
#  'proposals': 6633,
#  'jolly': 31894,
#  'hormone': 8551,
#  'mpls': 14752,
#  'bartle': 37433,
#  'befell': 47997,
#  'shadowy': 27960,
#  'stipulates': 30109,
#  'blatantly': 30965,
#  'witten': 29740,
#  'pythagoras': 20428,
#  'wind': 2251,
#  'compartment': 22516,
#  'pasadena': 18202,
#  'causality': 15780,
#  'ros': 21773,
#  'computability': 21298,
#  'hatched': 27961,
#  'ulein': 40181,
#  'ttt': 44044,
#  'interceptor': 21467,
#  'mentions': 5498,
#  'undated': 42985,
#  'inconspicuous': 41963,
#  'pragmatism': 18099,
#  'wolverine': 22810,
#  'fears': 8244,
#  'rationing': 27496,
#  'app': 25643,
#  'polishing': 25429,
#  'indebted': 18917,
#  'hafez': 37444,
#  'sarcastic': 23738,
#  'absurdity': 27627,
#  'cardoso': 39754,
#  'manzarek': 47756,
#  'inductor': 19226,
#  'osprey': 31584,
#  'tex': 10343,
#  'helmets': 17143,
#  'plotted': 17195,
#  'koko': 43875,
#  'adin': 32817,
#  'autographs': 47904,
#  'cezanne': 42436,
#  'springtime': 35214,
#  'sil': 18397,
#  'reassure': 44046,
#  'fortified': 10939,
#  'finish': 4812,
#  'observatories': 26322,
#  'avc': 40582,
#  'rooney': 31224,
#  'unwise': 34348,
#  'specialising': 33802,
#  'audiences': 5688,
#  'psilocybin': 25766,
#  'minivans': 34949,
#  'conceals': 41021,
#  'illa': 47906,
#  'fullback': 26610,
#  'rodham': 19909,
#  'levi': 12647,
#  'rebuild': 11498,
#  'gumby': 18156,
#  'atlanta': 3483,
#  'budd': 27628,
#  'looters': 27962,
#  'maeshowe': 43533,
#  'infusion': 18684,
#  'tumours': 36752,
#  'eddington': 16027,
#  'diminishes': 37840,
#  'miata': 19037,
#  'prophesy': 42986,
#  'modal': 12597,
#  'namibia': 10292,
#  'gfdl': 19371,
#  'specialise': 37434,
#  'hauge': 47907,
#  'sh': 5635,
#  'breakout': 21631,
#  'puente': 47138,
#  'druid': 18621,
#  'embarked': 10856,
#  'nativity': 17011,
#  'csv': 41022,
#  'humorists': 33804,
#  'clays': 30324,
#  'christology': 19626,
#  'machen': 46667,
#  'tailed': 17413,
#  'tony': 3242,
#  'baltasar': 36415,
#  'albarn': 34085,
#  'jammu': 19910,
#  'pauling': 17414,
#  'clarification': 24329,
#  'expressionist': 23231,
#  'polypropylene': 47139,
#  'inventory': 8348,
#  'limited': 752,
#  'handle': 3849,
#  'quran': 34086,
#  'inferno': 21632,
#  'laboratories': 9645,
#  'chaim': 23523,
#  'falconiformes': 36688,
#  'depreciation': 32149,
#  'usemodwiki': 49341,
#  'eras': 10954,
#  'sacks': 24401,
#  'custer': 31895,
#  'circulates': 45857,
#  'abelian': 9471,
#  'unpublished': 10736,
#  'fib': 49365,
#  'meanwhile': 3844,
#  'timeframe': 26611,
#  'carelessness': 48630,
#  'aum': 45285,
#  'seljuk': 16545,
#  'articles': 1098,
#  'hogeschool': 36416,
#  'loves': 10697,
#  'preferable': 16052,
#  'undecided': 44049,
#  'grahame': 43534,
#  'unfilled': 41023,
#  'monuments': 7916,
#  'incorporate': 6800,
#  'injures': 27054,
#  'glosses': 31657,
#  'transgenic': 26478,
#  'cir': 38564,
#  'coconuts': 38177,
#  'taxonomy': 9421,
#  'leprosy': 28169,
#  'homeowners': 42454,
#  'harker': 31225,
#  'hunyadi': 49220,
#  'lockhart': 49342,
#  'hillsides': 45241,
#  'cameos': 28835,
#  'explicated': 44050,
#  'anthemius': 35215,
#  'christine': 9962,
#  'nuevo': 27498,
#  'xn': 22255,
#  'realist': 18498,
#  'doorstep': 37435,
#  'withdrew': 5744,
#  'kettering': 44916,
#  'certain': 425,
#  'retelling': 19911,
#  'abolishing': 19558,
#  'andechs': 40184,
#  'empirically': 20507,
#  'virginal': 41258,
#  'grossman': 29020,
#  'diatomaceous': 41024,
#  'catalana': 42988,
#  'teen': 11367,
#  'biro': 40565,
#  'diglossia': 43552,
#  'kor': 28115,
#  'mecha': 10495,
#  'audiobook': 25506,
#  'prosecution': 6516,
#  'signatory': 14824,
#  'peerages': 36417,
#  'incompatibilities': 36078,
#  'adherence': 12794,
#  'copies': 3077,
#  'hijacked': 17197,
#  'ribbon': 11954,
#  'belong': 3810,
#  'oft': 16784,
#  'usury': 27352,
#  'excision': 26469,
#  'scotsman': 23117,
#  'venetia': 40566,
#  'declining': 8256,
#  'outre': 34349,
#  'dt': 10478,
#  'projectors': 27500,
#  'rainforests': 26470,
#  'activation': 11202,
#  'nez': 16633,
#  'speaking': 1196,
#  'solidification': 48606,
#  'empiricists': 29021,
#  'naps': 44616,
#  'associations': 5835,
#  'shares': 4090,
#  'saddened': 38936,
#  'rains': 13874,
#  'characterization': 11519,
#  'unfit': 19038,
#  'valentin': 31658,
#  'loads': 13796,
#  'mate': 7542,
#  'laetrile': 43556,
#  'singh': 8272,
#  'msnbc': 26039,
#  'apteryx': 45242,
#  'remembers': 22610,
#  'destructive': 7588,
#  'vocalized': 41025,
#  'unrelated': 6706,
#  'decimus': 34652,
#  'anzus': 27788,
#  'pigmented': 36079,
#  'kol': 36418,
#  'attributes': 4577,
#  'wits': 31451,
#  'allergy': 26899,
#  'duel': 12980,
#  'aids': 2759,
#  'hexameter': 24049,
#  'paisley': 31300,
#  'fondly': 31682,
#  'guerrillas': 12676,
#  'colored': 5386,
#  'borman': 19223,
#  'subordination': 35366,
#  'vocals': 4600,
#  'hermon': 30325,
#  'violates': 14682,
#  'saltwater': 27042,
#  'mapped': 11836,
#  'sauer': 46470,
#  'limes': 42437,
#  'biarritz': 39757,
#  'swallows': 36080,
#  'expensive': 2416,
#  'okinawan': 24625,
#  'wct': 42438,
#  'intestine': 22353,
#  'sovereignty': 3416,
#  'seifert': 38961,
#  'posture': 16456,
#  'partners': 3672,
#  'morley': 17389,
#  'marshall': 3144,
#  'fernand': 24526,
#  'etonians': 41495,
#  'kalinga': 34350,
#  'atonement': 13244,
#  'ksc': 30549,
#  'fatwas': 37453,
#  'obese': 28116,
#  'bacharach': 41026,
#  'antibacterial': 36843,
#  'salford': 23845,
#  'conte': 33805,
#  'worries': 29373,
#  'wharf': 18713,
#  'mo': 9305,
#  'manuals': 14163,
#  'lecompton': 49344,
#  'woolwich': 30326,
#  'ergative': 31453,
#  'locomotive': 8128,
#  'flipping': 26323,
#  'morrill': 35920,
#  'morocco': 3382,
#  'osage': 44617,
#  'defenseless': 41522,
#  'sesotho': 40186,
#  'glide': 16362,
#  'relocating': 25891,
#  'designs': 2293,
#  'subterranean': 21373,
#  'quart': 43883,
#  'qd': 26755,
#  'vaccinium': 44243,
#  'shema': 32364,
#  'boyars': 46360,
#  'gospel': 2044,
#  'hybrid': 6207,
#  'kamala': 43536,
#  'kenyan': 21746,
#  'registrations': 46668,
#  'pars': 44917,
#  'porous': 20270,
#  'inspired': 1616,
#  'nerves': 15275,
#  'mj': 24284,
#  'latter': 867,
#  'palau': 20707,
#  'relatives': 4820,
#  'gentrification': 39758,
#  'wildcat': 31896,
#  'leg': 3650,
#  'svetlana': 31659,
#  'transmembrane': 30219,
#  'subfield': 20100,
#  'travancore': 37457,
#  'harmonizing': 46452,
#  'chick': 10715,
#  'steampunk': 37841,
#  'daw': 39759,
#  'devoutly': 41965,
#  'sore': 26040,
#  'retinal': 43537,
#  'lacanian': 39323,
#  'bureaucracies': 41193,
#  'brunei': 6567,
#  'forgetting': 20301,
#  'motala': 26041,
#  'bright': 4322,
#  'camp': 2057,
#  'highlighting': 21475,
#  'deptford': 39499,
#  'stranded': 14272,
#  'snows': 30686,
#  'ecosystem': 10427,
#  'eiji': 42990,
#  'moving': 1330,
#  'eee': 36753,
#  'canonically': 38565,
#  'acknowledgment': 30550,
#  'prognosis': 22517,
#  'someone': 2021,
#  'rival': 3649,
#  'tailback': 47910,
#  'athos': 24410,
#  'ould': 19832,
#  'foodcrops': 42439,
#  'clowns': 12930,
#  'abuser': 46744,
#  'dominatrix': 26042,
#  'khmer': 6785,
#  'treasures': 11866,
#  'suzanne': 21795,
#  'undergraduates': 22611,
#  'maximized': 39785,
#  'probe': 6735,
#  'sui': 21633,
#  'adsorption': 37691,
#  'prays': 36105,
#  'fpu': 15101,
#  'plaintexts': 30561,
#  'midwifery': 21149,
#  'unbelief': 31441,
#  'lynx': 8442,
#  'kushner': 37113,
#  'nausica': 48879,
#  'plato': 5213,
#  'decrypts': 44618,
#  'clin': 26324,
#  'kwame': 34964,
#  'knocks': 29375,
#  'colossal': 22154,
#  'habitability': 47911,
#  'surfin': 44626,
#  'rko': 19913,
#  'cygwin': 21796,
#  'abingdon': 24871,
#  'records': 954,
#  'regnal': 24626,
#  'sextus': 32353,
#  'wife': 820,
#  'bethlehem': 11689,
#  'antagonism': 24973,
#  'genealogies': 30327,
#  'newtonian': 11771,
#  'lyon': 10415,
#  'decoded': 26612,
#  'newspapers': 3503,
#  'player': 284,
#  'greenberg': 11103,
#  'josephus': 8483,
#  'buddhas': 34653,
#  'nebuchadnezzar': 15160,
#  'athletic': 5508,
#  'covertly': 27958,
#  'ester': 16634,
#  'rim': 11640,
#  'medway': 41966,
#  'moustache': 30755,
#  'euphoric': 37842,
#  'lang': 7407,
#  'rhys': 24402,
#  'productivity': 9367,
#  'superb': 17569,
#  'irrigation': 9832,
#  'shovel': 44051,
#  'greatest': 1309,
#  'cathedral': 3191,
#  'colloquially': 11211,
#  'cryogenics': 27027,
#  'helpful': 9197,
#  'component': 2605,
#  'glycolipids': 46473,
#  'sympathizers': 22430,
#  'tarantino': 38567,
#  'treize': 40506,
#  'serb': 13538,
#  'kathmandu': 18799,
#  'trolling': 14311,
#  'lifeless': 33315,
#  'pople': 47142,
#  'suction': 29022,
#  'anabolic': 34951,
#  'lend': 14623,
#  'hedonism': 23118,
#  'equilateral': 36419,
#  'dirkjan': 41533,
#  'devices': 1625,
#  'sybil': 27211,
#  'baikonur': 49347,
#  'kayak': 17846,
#  'sundays': 15419,
#  'stable': 2412,
#  'veal': 49348,
#  'commonest': 42991,
#  'magnates': 29316,
#  'chubut': 47913,
#  'galba': 25892,
#  'jalalabad': 37436,
#  'assam': 32818,
#  'fsb': 33312,
#  'fatal': 5943,
#  'zadar': 47914,
#  'preserves': 12505,
#  'obscure': 6599,
#  'tamers': 38750,
#  'horses': 3565,
#  'moods': 16874,
#  'dalai': 14624,
#  'beverage': 10675,
#  'umno': 25507,
#  'servants': 8374,
#  'chitin': 35508,
#  'notably': 1225,
#  'lodger': 36081,
#  'arse': 31661,
#  'inked': 39692,
#  'conclusions': 7099,
#  'heathers': 30110,
#  'trait': 11066,
#  'faunas': 44621,
#  'pianos': 21527,
#  'dubliners': 34375,
#  'yards': 4715,
#  'satellite': 1939,
#  'lexicon': 11520,
#  'rove': 30111,
#  'datatypes': 38937,
#  'revised': 3638,
#  'jar': 16150,
#  'bass': 1519,
#  'corvus': 33316,
#  'blount': 41029,
#  'alcohols': 13142,
#  'townhouse': 47143,
#  'hispania': 16873,
#  'taxis': 16024,
#  'mackenzie': 12118,
#  'fondness': 21866,
#  'hamster': 8657,
#  'uda': 38938,
#  'tunny': 44622,
#  'clifford': 10786,
#  'itosu': 49350,
#  'ccitt': 27060,
#  'politically': 4220,
#  'confederal': 49351,
#  'hone': 39793,
#  'printers': 8623,
#  'viridian': 48845,
#  'clarifies': 39620,
#  'gepids': 47915,
#  'publicise': 49352,
#  'thoreau': 28118,
#  'kryptonians': 34378,
#  'foy': 45047,
#  'ks': 19628,
#  'pretensions': 37437,
#  'tents': 22997,
#  'jailed': 17200,
#  'cosmogony': 33806,
#  'integrable': 19833,
#  'poincar': 17938,
#  'emulated': 19972,
#  'cutlery': 44623,
#  'mesozoic': 21468,
#  'healthy': 5956,
#  'snaps': 30112,
#  'batteries': 8096,
#  'siddeley': 26295,
#  'multipoint': 44154,
#  'multipliers': 44052,
#  'torsion': 21642,
#  'hine': 48607,
#  'ortho': 42473,
#  'amylase': 38939,
#  'pruitt': 38180,
#  'tyne': 24050,
#  'clara': 12083,
#  'beautiful': 3024,
#  'petr': 29911,
#  'spruce': 21296,
#  'ramayana': 31228,
#  'savoie': 46474,
#  'conform': 10306,
#  'pomeranian': 24861,
#  'unwarranted': 33807,
#  'ibadi': 41967,
#  'modifying': 13514,
#  'vesuvius': 40187,
#  'llama': 12422,
#  'japonic': 49466,
#  'orphanage': 21469,
#  'bootlegged': 47145,
#  'cosimo': 24505,
#  'freelance': 18967,
#  'plays': 1658,
#  'sexy': 26043,
#  'referred': 577,
#  'astrologers': 21374,
#  'legionaries': 44053,
#  'rough': 4911,
#  'pollard': 27790,
#  'battle': 377,
#  'season': 610,
#  'train': 2298,
#  'makeshift': 33317,
#  'pacemakers': 35795,
#  'bakongo': 49335,
#  'capra': 17785,
#  'escalators': 19224,
#  'talladega': 46475,
#  'gastric': 32592,
#  'desmo': 49353,
#  'invisible': 6962,
#  'projective': 17585,
#  'loy': 48604,
#  'nets': 17570,
#  'winters': 6579,
#  'aficionados': 29755,
#  'chatham': 26613,
#  'cherished': 30967,
#  'mok': 34000,
#  'bother': 20848,
#  'borges': 8246,
#  'fifty': 4352,
#  'skinned': 22518,
#  'ouaddai': 32593,
#  'forest': 2299,
#  'mississippi': 2829,
#  'meltdown': 27629,
#  'segmentation': 27791,
#  'governing': 3836,
#  'cavendish': 19304,
#  'pdi': 44054,
#  'brew': 17520,
#  'transcriptase': 35791,
#  'reacts': 13942,
#  'rubric': 44624,
#  'qua': 35218,
#  'katha': 49354,
#  'derogatory': 12772,
#  'worldwide': 2043,
#  'inmates': 16233,
#  'domingo': 17257,
#  'retake': 21470,
#  'meteor': 11394,
#  'labs': 10103,
#  'teenagers': 12795,
#  'rrna': 38063,
#  'elected': 669,
#  'uk': 532,
#  'invests': 48849,
#  'clonic': 41543,
#  'kenjutsu': 38941,
#  'quiz': 15132,
#  'talmudic': 15505,
#  'door': 2931,
#  'anemia': 20911,
#  'ended': 1389,
#  'magazine': 1070,
#  'bhindranwale': 45999,
#  'affirmation': 19233,
#  'esquire': 31898,
#  'libra': 23646,
#  'nlm': 35509,
#  'embedding': 24506,
#  'textiles': 8984,
#  'deirdre': 31229,
#  'ensuing': 9034,
#  'ammonium': 16025,
#  'startup': 20163,
#  'kali': 14260,
#  'vainly': 46476,
#  'secreted': 23524,
#  'sadler': 32151,
#  'newbie': 30883,
#  'escaping': 13730,
#  'timberlake': 49523,
#  'deposed': 6830,
#  'napkin': 48608,
#  'hanja': 23909,
#  'studi': 26471,
#  'horticulture': 28837,
#  'sandworms': 47146,
#  'dualities': 38942,
#  'heth': 46477,
#  'editor': 2266,
#  'climatic': 13232,
#  'summarised': 22479,
#  'robin': 5005,
#  'camouflage': 9593,
#  'cryptosystems': 34654,
#  'antichrist': 14376,
#  'victorious': 8816,
#  'shrubs': 17009,
#  'gatwick': 41498,
#  'cong': 20646,
#  'ainu': 12138,
#  'slade': 37279,
#  'wastes': 11731,
#  'granny': 26614,
#  'croat': 24051,
#  'round': 1189,
#  'ethnomusicology': 34354,
#  'outlived': 33319,
#  'rectum': 25099,
#  'inhibitor': 18277,
#  'pigeons': 25639,
#  'rodolfo': 34355,
#  'mars': 2377,
#  'halle': 16899,
#  'bamboo': 12744,
#  'degraded': 20508,
#  'eisteddfod': 45243,
#  'spawning': 20229,
#  'airliner': 15002,
#  'agnetha': 31230,
#  'murat': 27354,
#  'coinciding': 30969,
#  'profiles': 12139,
#  'liars': 26901,
#  'consistency': 9127,
#  'minimum': 2751,
#  'twists': 24862,
#  'properties': 1109,
#  'kurz': 47148,
#  'doubts': 12239,
#  'segmented': 26044,
#  'rewrote': 34655,
#  'astray': 34356,
#  'ota': 44625,
#  'unacceptably': 43238,
#  'maranh': 47150,
#  'magically': 41970,
#  'lovin': 40567,
#  'radium': 24235,
#  'doing': 2058,
#  'benhavn': 47918,
#  'flaps': 23846,
#  'fellowship': 8406,
#  'stellated': 47159,
#  'grave': 4570,
#  'obsolescence': 41551,
#  'typographical': 24975,
#  'proviso': 40568,
#  'samsung': 34952,
#  'holmes': 7818,
#  'faces': 4078,
#  'gamba': 34357,
#  'sued': 9103,
#  'trio': 7852,
#  'swam': 36420,
#  'cordillera': 17997,
#  'suggests': 2393,
#  'interactionism': 44055,
#  'radar': 4544,
#  'colour': 3212,
#  'cheaply': 23119,
#  'autonomic': 31663,
#  'revolving': 20164,
#  'straw': 14231,
#  'jeopardy': 16417,
#  'buns': 38944,
#  'rw': 16546,
#  'installations': 11368,
#  'turgot': 48696,
#  'peat': 14472,
#  'circled': 31664,
#  'lasted': 4072,
#  'dmc': 44244,
#  'all': 50,
#  'bros': 9398,
#  'usability': 15426,
#  'archaeopteryx': 20231,
#  'enforcing': 15348,
#  'affine': 23954,
#  'thunderstorms': 19305,
#  'sat': 6948,
#  'ghc': 44056,
#  'screens': 9158,
#  'arthropod': 34656,
#  'teg': 19165,
#  'handbuch': 44156,
#  'alphonso': 26902,
#  'hybrids': 16875,
#  'linseed': 42993,
#  'downy': 44758,
#  'ahura': 31463,
#  'deux': 23847,
#  'despotate': 37114,
#  'mulder': 45900,
#  'trajan': 18278,
#  'bilayer': 32819,
#  'predicted': 4908,
#  'rebound': 19496,
#  'forties': 28265,
#  'shao': 49591,
#  're': 632,
#  'cleves': 48610,
#  'howstuffworks': 31231,
#  'goat': 8196,
#  'sven': 32354,
#  ...}

# %%
reverse_dictionary
# Out:
# {0: 'UNK',
#  1: 'the',
#  2: 'of',
#  3: 'and',
#  4: 'one',
#  5: 'in',
#  6: 'a',
#  7: 'to',
#  8: 'zero',
#  9: 'nine',
#  10: 'two',
#  11: 'is',
#  12: 'as',
#  13: 'eight',
#  14: 'for',
#  15: 's',
#  16: 'five',
#  17: 'three',
#  18: 'was',
#  19: 'by',
#  20: 'that',
#  21: 'four',
#  22: 'six',
#  23: 'seven',
#  24: 'with',
#  25: 'on',
#  26: 'are',
#  27: 'it',
#  28: 'from',
#  29: 'or',
#  30: 'his',
#  31: 'an',
#  32: 'be',
#  33: 'this',
#  34: 'which',
#  35: 'at',
#  36: 'he',
#  37: 'also',
#  38: 'not',
#  39: 'have',
#  40: 'were',
#  41: 'has',
#  42: 'but',
#  43: 'other',
#  44: 'their',
#  45: 'its',
#  46: 'first',
#  47: 'they',
#  48: 'some',
#  49: 'had',
#  50: 'all',
#  51: 'more',
#  52: 'most',
#  53: 'can',
#  54: 'been',
#  55: 'such',
#  56: 'many',
#  57: 'who',
#  58: 'new',
#  59: 'used',
#  60: 'there',
#  61: 'after',
#  62: 'when',
#  63: 'into',
#  64: 'american',
#  65: 'time',
#  66: 'these',
#  67: 'only',
#  68: 'see',
#  69: 'may',
#  70: 'than',
#  71: 'world',
#  72: 'i',
#  73: 'b',
#  74: 'would',
#  75: 'd',
#  76: 'no',
#  77: 'however',
#  78: 'between',
#  79: 'about',
#  80: 'over',
#  81: 'years',
#  82: 'states',
#  83: 'people',
#  84: 'war',
#  85: 'during',
#  86: 'united',
#  87: 'known',
#  88: 'if',
#  89: 'called',
#  90: 'use',
#  91: 'th',
#  92: 'system',
#  93: 'often',
#  94: 'state',
#  95: 'so',
#  96: 'history',
#  97: 'will',
#  98: 'up',
#  99: 'while',
#  100: 'where',
#  101: 'city',
#  102: 'being',
#  103: 'english',
#  104: 'then',
#  105: 'any',
#  106: 'both',
#  107: 'under',
#  108: 'out',
#  109: 'made',
#  110: 'well',
#  111: 'her',
#  112: 'e',
#  113: 'number',
#  114: 'government',
#  115: 'them',
#  116: 'm',
#  117: 'later',
#  118: 'since',
#  119: 'him',
#  120: 'part',
#  121: 'name',
#  122: 'c',
#  123: 'century',
#  124: 'through',
#  125: 'because',
#  126: 'x',
#  127: 'university',
#  128: 'early',
#  129: 'life',
#  130: 'british',
#  131: 'year',
#  132: 'like',
#  133: 'same',
#  134: 'including',
#  135: 'became',
#  136: 'example',
#  137: 'day',
#  138: 'each',
#  139: 'even',
#  140: 'work',
#  141: 'language',
#  142: 'although',
#  143: 'several',
#  144: 'form',
#  145: 'john',
#  146: 'u',
#  147: 'national',
#  148: 'very',
#  149: 'much',
#  150: 'g',
#  151: 'french',
#  152: 'before',
#  153: 'general',
#  154: 'what',
#  155: 't',
#  156: 'against',
#  157: 'n',
#  158: 'high',
#  159: 'links',
#  160: 'could',
#  161: 'based',
#  162: 'those',
#  163: 'now',
#  164: 'second',
#  165: 'de',
#  166: 'music',
#  167: 'another',
#  168: 'large',
#  169: 'she',
#  170: 'f',
#  171: 'external',
#  172: 'german',
#  173: 'different',
#  174: 'modern',
#  175: 'great',
#  176: 'do',
#  177: 'common',
#  178: 'set',
#  179: 'list',
#  180: 'south',
#  181: 'series',
#  182: 'major',
#  183: 'game',
#  184: 'power',
#  185: 'long',
#  186: 'country',
#  187: 'king',
#  188: 'law',
#  189: 'group',
#  190: 'film',
#  191: 'still',
#  192: 'until',
#  193: 'north',
#  194: 'international',
#  195: 'term',
#  196: 'we',
#  197: 'end',
#  198: 'book',
#  199: 'found',
#  200: 'own',
#  201: 'political',
#  202: 'party',
#  203: 'order',
#  204: 'usually',
#  205: 'president',
#  206: 'church',
#  207: 'you',
#  208: 'death',
#  209: 'theory',
#  210: 'area',
#  211: 'around',
#  212: 'include',
#  213: 'god',
#  214: 'ii',
#  215: 'way',
#  216: 'did',
#  217: 'military',
#  218: 'population',
#  219: 'using',
#  220: 'though',
#  221: 'small',
#  222: 'following',
#  223: 'within',
#  224: 'non',
#  225: 'left',
#  226: 'human',
#  227: 'main',
#  228: 'among',
#  229: 'point',
#  230: 'r',
#  231: 'due',
#  232: 'p',
#  233: 'considered',
#  234: 'public',
#  235: 'popular',
#  236: 'computer',
#  237: 'west',
#  238: 'family',
#  239: 'east',
#  240: 'information',
#  241: 'important',
#  242: 'european',
#  243: 'man',
#  244: 'sometimes',
#  245: 'right',
#  246: 'old',
#  247: 'free',
#  248: 'word',
#  249: 'without',
#  250: 'last',
#  251: 'us',
#  252: 'members',
#  253: 'given',
#  254: 'times',
#  255: 'roman',
#  256: 'make',
#  257: 'h',
#  258: 'age',
#  259: 'place',
#  260: 'l',
#  261: 'thus',
#  262: 'science',
#  263: 'case',
#  264: 'become',
#  265: 'systems',
#  266: 'union',
#  267: 'born',
#  268: 'york',
#  269: 'line',
#  270: 'countries',
#  271: 'does',
#  272: 'isbn',
#  273: 'st',
#  274: 'control',
#  275: 'various',
#  276: 'others',
#  277: 'house',
#  278: 'article',
#  279: 'island',
#  280: 'should',
#  281: 'led',
#  282: 'back',
#  283: 'period',
#  284: 'player',
#  285: 'europe',
#  286: 'languages',
#  287: 'central',
#  288: 'water',
#  289: 'few',
#  290: 'western',
#  291: 'home',
#  292: 'began',
#  293: 'generally',
#  294: 'less',
#  295: 'k',
#  296: 'similar',
#  297: 'written',
#  298: 'original',
#  299: 'best',
#  300: 'must',
#  301: 'according',
#  302: 'school',
#  303: 'france',
#  304: 'air',
#  305: 'single',
#  306: 'force',
#  307: 'v',
#  308: 'land',
#  309: 'groups',
#  310: 'down',
#  311: 'how',
#  312: 'works',
#  313: 'development',
#  314: 'official',
#  315: 'support',
#  316: 'england',
#  317: 'j',
#  318: 'rather',
#  319: 'data',
#  320: 'space',
#  321: 'greek',
#  322: 'km',
#  323: 'named',
#  324: 'germany',
#  325: 'just',
#  326: 'games',
#  327: 'said',
#  328: 'version',
#  329: 'late',
#  330: 'earth',
#  331: 'company',
#  332: 'every',
#  333: 'economic',
#  334: 'short',
#  335: 'published',
#  336: 'black',
#  337: 'army',
#  338: 'off',
#  339: 'london',
#  340: 'million',
#  341: 'body',
#  342: 'field',
#  343: 'christian',
#  344: 'either',
#  345: 'empire',
#  346: 'social',
#  347: 'o',
#  348: 'developed',
#  349: 'standard',
#  350: 'court',
#  351: 'service',
#  352: 'kingdom',
#  353: 'along',
#  354: 'college',
#  355: 'republic',
#  356: 'sea',
#  357: 'america',
#  358: 'today',
#  359: 'result',
#  360: 'held',
#  361: 'team',
#  362: 'light',
#  363: 'means',
#  364: 'never',
#  365: 'especially',
#  366: 'third',
#  367: 'further',
#  368: 'character',
#  369: 'forces',
#  370: 'take',
#  371: 'men',
#  372: 'society',
#  373: 'show',
#  374: 'open',
#  375: 'possible',
#  376: 'fact',
#  377: 'battle',
#  378: 'took',
#  379: 'former',
#  380: 'books',
#  381: 'soviet',
#  382: 'river',
#  383: 'children',
#  384: 'having',
#  385: 'good',
#  386: 'local',
#  387: 'current',
#  388: 'son',
#  389: 'process',
#  390: 'natural',
#  391: 'present',
#  392: 'himself',
#  393: 'islands',
#  394: 'total',
#  395: 'near',
#  396: 'white',
#  397: 'days',
#  398: 'person',
#  399: 'itself',
#  400: 'seen',
#  401: 'culture',
#  402: 'little',
#  403: 'above',
#  404: 'software',
#  405: 'largest',
#  406: 'words',
#  407: 'upon',
#  408: 'level',
#  409: 'father',
#  410: 'side',
#  411: 'created',
#  412: 'red',
#  413: 'references',
#  414: 'press',
#  415: 'full',
#  416: 'region',
#  417: 'almost',
#  418: 'al',
#  419: 'image',
#  420: 'famous',
#  421: 'play',
#  422: 'came',
#  423: 'role',
#  424: 'once',
#  425: 'certain',
#  426: 'league',
#  427: 'jewish',
#  428: 'james',
#  429: 'january',
#  430: 'site',
#  431: 'again',
#  432: 'art',
#  433: 'numbers',
#  434: 'member',
#  435: 'areas',
#  436: 'movement',
#  437: 'religious',
#  438: 'type',
#  439: 'march',
#  440: 'community',
#  441: 'story',
#  442: 'played',
#  443: 'production',
#  444: 'released',
#  445: 'center',
#  446: 'rights',
#  447: 'real',
#  448: 'related',
#  449: 'foreign',
#  450: 'low',
#  451: 'ancient',
#  452: 'terms',
#  453: 'view',
#  454: 'source',
#  455: 'act',
#  456: 'minister',
#  457: 'change',
#  458: 'energy',
#  459: 'produced',
#  460: 'research',
#  461: 'actor',
#  462: 'making',
#  463: 'december',
#  464: 'civil',
#  465: 'women',
#  466: 'special',
#  467: 'style',
#  468: 'william',
#  469: 'japanese',
#  470: 'design',
#  471: 'available',
#  472: 'chinese',
#  473: 'forms',
#  474: 'canada',
#  475: 'northern',
#  476: 'died',
#  477: 'class',
#  478: 'living',
#  479: 'next',
#  480: 'particular',
#  481: 'program',
#  482: 'council',
#  483: 'television',
#  484: 'head',
#  485: 'david',
#  486: 'china',
#  487: 'middle',
#  488: 'established',
#  489: 'hand',
#  490: 'bc',
#  491: 'far',
#  492: 'july',
#  493: 'function',
#  494: 'position',
#  495: 'y',
#  496: 'built',
#  497: 'george',
#  498: 'band',
#  499: 'together',
#  500: 'w',
#  501: 'latin',
#  502: 'thought',
#  503: 'eastern',
#  504: 'charles',
#  505: 'parts',
#  506: 'instead',
#  507: 'study',
#  508: 'might',
#  509: 'india',
#  510: 'code',
#  511: 'included',
#  512: 'meaning',
#  513: 'trade',
#  514: 'per',
#  515: 'june',
#  516: 'least',
#  517: 'half',
#  518: 'model',
#  519: 'economy',
#  520: 'prime',
#  521: 'traditional',
#  522: 'always',
#  523: 'capital',
#  524: 'range',
#  525: 'emperor',
#  526: 'november',
#  527: 'young',
#  528: 'anti',
#  529: 'final',
#  530: 'text',
#  531: 'players',
#  532: 'uk',
#  533: 'april',
#  534: 'run',
#  535: 'september',
#  536: 'radio',
#  537: 'addition',
#  538: 'live',
#  539: 'august',
#  540: 'note',
#  541: 'taken',
#  542: 'italian',
#  543: 'lost',
#  544: 'nature',
#  545: 'project',
#  546: 'technology',
#  547: 'spanish',
#  548: 'october',
#  549: 'recent',
#  550: 'rate',
#  551: 'won',
#  552: 'true',
#  553: 'value',
#  554: 'uses',
#  555: 'russian',
#  556: 'est',
#  557: 'wrote',
#  558: 'effect',
#  559: 'album',
#  560: 'southern',
#  561: 'africa',
#  562: 'whose',
#  563: 'top',
#  564: 'historical',
#  565: 'australia',
#  566: 'catholic',
#  567: 'particularly',
#  568: 'self',
#  569: 'structure',
#  570: 'record',
#  571: 'evidence',
#  572: 'rule',
#  573: 'themselves',
#  574: 'influence',
#  575: 'cases',
#  576: 'subject',
#  577: 'referred',
#  578: 'continued',
#  579: 'nations',
#  580: 'rock',
#  581: 'below',
#  582: 'japan',
#  583: 'com',
#  584: 'song',
#  585: 'throughout',
#  586: 'names',
#  587: 'female',
#  588: 'title',
#  589: 'therefore',
#  590: 'our',
#  591: 'office',
#  592: 'star',
#  593: 'paul',
#  594: 'too',
#  595: 'cities',
#  596: 'independent',
#  597: 'february',
#  598: 'author',
#  599: 'problem',
#  600: 'species',
#  601: 'education',
#  602: 'done',
#  603: 'philosophy',
#  604: 'come',
#  605: 'higher',
#  606: 'originally',
#  607: 'market',
#  608: 'town',
#  609: 'my',
#  610: 'season',
#  611: 'love',
#  612: 'strong',
#  613: 'israel',
#  614: 'irish',
#  615: 'writer',
#  616: 'films',
#  617: 'elements',
#  618: 'robert',
#  619: 'whether',
#  620: 'despite',
#  621: 'eventually',
#  622: 'here',
#  623: 'football',
#  624: 'action',
#  625: 'internet',
#  626: 'sound',
#  627: 'individual',
#  628: 'network',
#  629: 'described',
#  630: 'practice',
#  631: 'characters',
#  632: 're',
#  633: 'royal',
#  634: 'la',
#  635: 'events',
#  636: 'formed',
#  637: 'commonly',
#  638: 'base',
#  639: 'received',
#  640: 'problems',
#  641: 'african',
#  642: 'food',
#  643: 'jews',
#  644: 'able',
#  645: 'male',
#  646: 'mass',
#  647: 'typically',
#  648: 'complex',
#  649: 'lower',
#  650: 'includes',
#  651: 'outside',
#  652: 'legal',
#  653: 'complete',
#  654: 'parliament',
#  655: 'significant',
#  656: 'actually',
#  657: 'business',
#  658: 'fiction',
#  659: 'physical',
#  660: 'followed',
#  661: 'deaths',
#  662: 'key',
#  663: 'leader',
#  664: 'widely',
#  665: 'page',
#  666: 'basic',
#  667: 'types',
#  668: 'henry',
#  669: 'elected',
#  670: 'beginning',
#  671: 'fire',
#  672: 'building',
#  673: 'independence',
#  674: 'went',
#  675: 'movie',
#  676: 'aircraft',
#  677: 'ever',
#  678: 'canadian',
#  679: 'material',
#  680: 'births',
#  681: 'video',
#  682: 'news',
#  683: 'future',
#  684: 'scientific',
#  685: 'simply',
#  686: 'go',
#  687: 'defined',
#  688: 'laws',
#  689: 'get',
#  690: 'close',
#  691: 'industry',
#  692: 'specific',
#  693: 'examples',
#  694: 'believe',
#  695: 'services',
#  696: 'idea',
#  697: 'method',
#  698: 'introduced',
#  699: 'points',
#  700: 'return',
#  701: 'cause',
#  702: 'indian',
#  703: 'britain',
#  704: 'features',
#  705: 'size',
#  706: 'majority',
#  707: 'post',
#  708: 'lead',
#  709: 'organization',
#  710: 'cannot',
#  711: 'designed',
#  712: 'ireland',
#  713: 'cross',
#  714: 'classical',
#  715: 'personal',
#  716: 'writing',
#  717: 'concept',
#  718: 'associated',
#  719: 'required',
#  720: 'soon',
#  721: 'changes',
#  722: 'california',
#  723: 'located',
#  724: 'sense',
#  725: 'believed',
#  726: 'started',
#  727: 'away',
#  728: 'co',
#  729: 'religion',
#  730: 'mother',
#  731: 'county',
#  732: 'rules',
#  733: 'studies',
#  734: 'yet',
#  735: 'find',
#  736: 'knowledge',
#  737: 'put',
#  738: 'founded',
#  739: 'policy',
#  740: 'currently',
#  741: 'provide',
#  742: 'working',
#  743: 'media',
#  744: 'election',
#  745: 'australian',
#  746: 'me',
#  747: 'thomas',
#  748: 'allowed',
#  749: 'russia',
#  750: 'greater',
#  751: 'earlier',
#  752: 'limited',
#  753: 'object',
#  754: 'brought',
#  755: 'online',
#  756: 'lord',
#  757: 'association',
#  758: 'mostly',
#  759: 'blue',
#  760: 'across',
#  761: 'constitution',
#  762: 'added',
#  763: 'interest',
#  764: 'things',
#  765: 'relations',
#  766: 'speed',
#  767: 'federal',
#  768: 'singer',
#  769: 'effects',
#  770: 'growth',
#  771: 'sources',
#  772: 'your',
#  773: 'remains',
#  774: 'z',
#  775: 'probably',
#  776: 'gave',
#  777: 'simple',
#  778: 'attack',
#  779: 'longer',
#  780: 'reference',
#  781: 'saint',
#  782: 'success',
#  783: 'killed',
#  784: 'past',
#  785: 'career',
#  786: 'need',
#  787: 'park',
#  788: 'definition',
#  789: 'say',
#  790: 'etc',
#  791: 'give',
#  792: 'peace',
#  793: 'chief',
#  794: 'stories',
#  795: 'security',
#  796: 'wide',
#  797: 'ball',
#  798: 'saw',
#  799: 'machine',
#  800: 'better',
#  801: 'cell',
#  802: 'leading',
#  803: 'becomes',
#  804: 'larger',
#  805: 'spain',
#  806: 'parties',
#  807: 'night',
#  808: 'products',
#  809: 'remained',
#  810: 'prize',
#  811: 'website',
#  812: 'months',
#  813: 'big',
#  814: 'money',
#  815: 'cultural',
#  816: 'territory',
#  817: 'help',
#  818: 'private',
#  819: 'moved',
#  820: 'wife',
#  821: 'letter',
#  822: 'politics',
#  823: 'lines',
#  824: 'largely',
#  825: 'contains',
#  826: 'companies',
#  827: 'lake',
#  828: 'perhaps',
#  829: 'green',
#  830: 'already',
#  831: 'iii',
#  832: 'dead',
#  833: 'library',
#  834: 'separate',
#  835: 'refer',
#  836: 'makes',
#  837: 'appeared',
#  838: 'dutch',
#  839: 'holy',
#  840: 'era',
#  841: 'novel',
#  842: 'successful',
#  843: 'italy',
#  844: 'letters',
#  845: 'results',
#  846: 'matter',
#  847: 'produce',
#  848: 'origin',
#  849: 'claim',
#  850: 'whole',
#  851: 'attempt',
#  852: 'directly',
#  853: 'actress',
#  854: 'surface',
#  855: 'revolution',
#  856: 'highly',
#  857: 'caused',
#  858: 'status',
#  859: 'musical',
#  860: 'richard',
#  861: 'commercial',
#  862: 'division',
#  863: 'color',
#  864: 'health',
#  865: 'release',
#  866: 'coast',
#  867: 'latter',
#  868: 'authority',
#  869: 'treaty',
#  870: 'turn',
#  871: 'michael',
#  872: 'nation',
#  873: 'direct',
#  874: 'asia',
#  875: 'edition',
#  876: 'programming',
#  877: 'playing',
#  878: 'date',
#  879: 'whom',
#  880: 'native',
#  881: 'mary',
#  882: 'married',
#  883: 'towards',
#  884: 'issues',
#  885: 'double',
#  886: 'basis',
#  887: 'primary',
#  888: 'allow',
#  889: 'enough',
#  890: 'memory',
#  891: 'reason',
#  892: 'web',
#  893: 'exist',
#  894: 'provided',
#  895: 'course',
#  896: 'oil',
#  897: 'functions',
#  898: 'chemical',
#  899: 'analysis',
#  900: 'alexander',
#  901: 'mid',
#  902: 'replaced',
#  903: 'queen',
#  904: 'tv',
#  905: 'sun',
#  906: 'claims',
#  907: 'literature',
#  908: 'metal',
#  909: 'amount',
#  910: 'divided',
#  911: 'blood',
#  912: 'likely',
#  913: 'access',
#  914: 'average',
#  915: 'length',
#  916: 'smaller',
#  917: 'medical',
#  918: 'property',
#  919: 'students',
#  920: 'degree',
#  921: 'elections',
#  922: 'club',
#  923: 'claimed',
#  924: 'performance',
#  925: 'director',
#  926: 'digital',
#  927: 'museum',
#  928: 'front',
#  929: 'difficult',
#  930: 'tradition',
#  931: 'nearly',
#  932: 'schools',
#  933: 'washington',
#  934: 'gas',
#  935: 'map',
#  936: 'jesus',
#  937: 'louis',
#  938: 'rome',
#  939: 'unit',
#  940: 'baseball',
#  941: 'mind',
#  942: 'peter',
#  943: 'mark',
#  944: 'collection',
#  945: 'product',
#  946: 'congress',
#  947: 'programs',
#  948: 'changed',
#  949: 'ideas',
#  950: 'moon',
#  951: 'entire',
#  952: 'user',
#  953: 'ground',
#  954: 'records',
#  955: 'frequently',
#  956: 'increase',
#  957: 'highest',
#  958: 'sent',
#  959: 'finally',
#  960: 'board',
#  961: 'don',
#  962: 'notable',
#  963: 'methods',
#  964: 'read',
#  965: 'recently',
#  966: 'bit',
#  967: 'variety',
#  968: 'involved',
#  969: 'call',
#  970: 'democratic',
#  971: 'ten',
#  972: 'served',
#  973: 'minor',
#  974: 'hard',
#  975: 'objects',
#  976: 'birth',
#  977: 'increased',
#  978: 'nuclear',
#  979: 'section',
#  980: 'street',
#  981: 'windows',
#  982: 'relatively',
#  983: 'car',
#  984: 'move',
#  985: 'create',
#  986: 'returned',
#  987: 'bank',
#  988: 'conditions',
#  989: 'operation',
#  990: 'adopted',
#  991: 'relationship',
#  992: 'christ',
#  993: 'hall',
#  994: 'appear',
#  995: 'rest',
#  996: 'child',
#  997: 'element',
#  998: 'appears',
#  999: 'takes',
#  ...}

# %%
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5240, 3084, 12, 6, 195, 2, 3135, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
batch
# Out:
# array([3084, 3084,   12,   12,    6,    6,  195,  195])

# %%
labels
# Out:
# array([[  12],
#        [5240],
#        [   6],
#        [3084],
#        [  12],
#        [ 195],
#        [   6],
#        [   2]])

# %%
data[:10]
# Out:
# [5240, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 12 as
# 3084 originated -> 5240 anarchism
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# %%
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

# %%
valid_examples
# Out:
# array([32, 16, 77, 48, 58, 93, 18, 73, 57, 43, 61, 67, 78, 60, 11,  1])

# %%
# Input data.
train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

# %%
embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))

# %%
embed = tf.nn.embedding_lookup(embeddings, train_inputs)

# %%
embed
# Out:
# <tf.Tensor 'embedding_lookup:0' shape=(128, 128) dtype=float32>

# %%
nce_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))

# %%
nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

# %%
loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

# %%
optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

# %%
norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
normalized_embeddings = embeddings / norm
valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)
# Out:
# WARNING:tensorflow:From <ipython-input-36-88e0086c644e>:1: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
init = tf.global_variables_initializer()

# %%
num_steps =100000

# %%
with tf.Session() as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  256.52764892578125
# Nearest to be: moulds, glottalized, oak, falsification, inexperienced, diamonds, trichomes, vyacheslav,
# Nearest to five: lubbock, sprayed, anonymously, chip, brushes, resembles, sport, battlefront,
# Nearest to however: printers, created, narrative, basset, langston, quieter, cloisters, chips,
# Nearest to some: caplan, siliceous, lingerie, partitioning, mews, bahri, buffett, ati,
# Nearest to new: tissue, emir, pokey, niva, spinning, consultations, stockade, lemay,
# Nearest to often: const, littoral, elegans, considers, sib, marinetti, multitasking, niels,
# Nearest to was: incorruptible, upwards, damon, crookes, talladega, acker, antigens, sharpen,
# Nearest to b: lysine, oro, lcd, calgary, boyfriend, elliott, harming, keanu,
# Nearest to who: victorians, leontopithecus, contemplating, insolvency, sherlock, suffixed, esaf, tempore,
# Nearest to other: timeline, etienne, madhu, yourdon, lt, urbanized, poses, merits,
# Nearest to after: position, visual, almonds, interesting, mockingbird, regulus, englewood, anthropogenic,
# Nearest to only: pivots, hbo, wrecking, interventionist, cpsu, kosova, cruising, internals,
# Nearest to between: luminiferous, evolves, toasting, slant, trampled, basilica, reduplication, decreased,
# Nearest to there: cathodes, ronaldo, endeavour, spicy, stick, bypass, placeholder, demetrius,
# Nearest to is: badlands, urgell, australis, furniture, dedications, belles, hussars, landmass,
# Nearest to the: dat, haarlem, jp, brakeman, bju, bilbo, gerund, czar,
# Average loss at step  2000 :  113.21874460983277
# Average loss at step  4000 :  52.602609758853916
# Average loss at step  6000 :  34.181943662166596
# Average loss at step  8000 :  23.89284397470951
# Average loss at step  10000 :  17.717645491600038
# Nearest to be: lymphoma, batting, moulds, o, diamonds, ll, gb, oak,
# Nearest to five: before, sport, national, that, japanese, resembles, archie, valentinian,
# Nearest to however: created, archie, narrative, complete, prove, digital, gb, dependencies,
# Nearest to some: in, with, basins, is, archie, advice, outwardly, and,
# Nearest to new: tissue, emir, libels, tendency, out, pueblo, archie, equilibrium,
# Nearest to often: nine, one, bckgr, archie, six, zero, five, milne,
# Nearest to was: a, and, UNK, his, one, mctaggart, bead, lymphoma,
# Nearest to b: agave, coke, originally, aquaculture, omega, lysine, rural, calgary,
# Nearest to who: burgess, laboratory, and, sherlock, poland, not, implicit, tempering,
# Nearest to other: timeline, gollancz, lt, pneumonia, advocates, possibly, cardinality, merits,
# Nearest to after: position, bckgr, interesting, visual, lack, virtual, transportation, properties,
# Nearest to only: lymphoma, nine, four, zero, images, eight, isbn, docked,
# Nearest to between: nine, zero, bckgr, lymphoma, six, coke, three, antimatter,
# Nearest to there: vogt, archie, austin, lymphoma, results, mountain, views, and,
# Nearest to is: victoriae, inside, hungarian, semi, australis, urgell, gollancz, landmass,
# Nearest to the: the, legs, along, priscus, proof, mctaggart, recorded, critic,
# Average loss at step  12000 :  14.054294873952866
# Average loss at step  14000 :  11.537291020154953
# Average loss at step  16000 :  9.690002275824547
# Average loss at step  18000 :  8.696531076788903
# Average loss at step  20000 :  7.709777731657028
# Nearest to be: moulds, lymphoma, batting, oak, ll, diamonds, but, latins,
# Nearest to five: that, before, valentinian, sport, japanese, walid, crash, infinite,
# Nearest to however: archie, narrative, created, printers, amazonas, cloisters, circ, digital,
# Nearest to some: with, in, is, by, was, dasyprocta, and, basins,
# Nearest to new: tissue, emir, out, pueblo, libels, tendency, spinning, agouti,
# Nearest to often: two, zero, five, six, four, nine, seven, agouti,
# Nearest to was: agouti, a, his, their, and, this, one, its,
# Nearest to b: agave, aquaculture, circ, originally, after, lysine, motifs, omega,
# Nearest to who: are, burgess, not, laboratory, was, sherlock, by, tempering,
# Nearest to other: timeline, gollancz, advocates, menstrual, pneumonia, elbow, lt, like,
# Nearest to after: bckgr, position, visual, interesting, dasyprocta, virtual, execute, operatorname,
# Nearest to only: lymphoma, four, docked, eight, amazonas, nine, birkenau, images,
# Nearest to between: zero, nine, eight, three, six, two, seven, four,
# Nearest to there: and, agouti, it, that, this, one, vogt, there,
# Nearest to is: and, inside, urgell, hungarian, victoriae, semi, australis, dictates,
# Nearest to the: the, their, agouti, s, legs, dasyprocta, a, operatorname,
# Average loss at step  22000 :  7.226910223722458
# Average loss at step  24000 :  6.9266649833917615
# Average loss at step  26000 :  6.631292400479317
# Average loss at step  28000 :  6.208380486011505
# Average loss at step  30000 :  6.199741893053055
# Nearest to be: batting, moulds, lymphoma, but, waas, ll, at, diamonds,
# Nearest to five: that, it, sport, chip, anonymously, valentinian, before, a,
# Nearest to however: created, printers, narrative, archie, digital, cloisters, dependencies, amazonas,
# Nearest to some: with, is, dasyprocta, by, and, circ, sponsors, was,
# Nearest to new: tissue, emir, out, agouti, libels, archie, omnibus, pokey,
# Nearest to often: six, seven, eight, five, four, nine, two, agouti,
# Nearest to was: agouti, a, its, their, this, his, one, dasyprocta,
# Nearest to b: agave, aquaculture, circ, after, fort, lysine, originally, motifs,
# Nearest to who: are, were, was, laboratory, tempering, burgess, not, by,
# Nearest to other: timeline, advocates, menstrual, gollancz, like, containers, elbow, merits,
# Nearest to after: bckgr, position, aba, visual, interesting, virtual, spotter, execute,
# Nearest to only: eight, four, docked, lymphoma, seven, five, cruising, amazonas,
# Nearest to between: six, eight, zero, four, seven, nine, three, two,
# Nearest to there: that, agouti, this, it, and, primigenius, also, one,
# Nearest to is: and, dictates, urgell, inside, soviet, trumpets, ssri, hungarian,
# Nearest to the: their, the, s, its, agouti, legs, a, her,
# Average loss at step  32000 :  5.865837483048439
# Average loss at step  34000 :  5.760476514697075
# Average loss at step  36000 :  5.753182576298713
# Average loss at step  38000 :  5.205561746478081
# Average loss at step  40000 :  5.500192476153374
# Nearest to be: but, batting, moulds, lymphoma, vma, though, on, that,
# Nearest to five: that, a, transferred, which, it, agouti, chip, haer,
# Nearest to however: printers, created, narrative, digital, archie, dependencies, cloisters, albury,
# Nearest to some: dasyprocta, operatorname, circ, is, by, with, sponsors, akimbo,
# Nearest to new: tissue, out, archie, agouti, these, emir, libels, amputation,
# Nearest to often: four, six, five, seven, eight, two, zero, nine,
# Nearest to was: agouti, their, its, a, his, this, one, dasyprocta,
# Nearest to b: agave, circ, but, after, aquaculture, and, fort, lysine,
# Nearest to who: are, was, were, be, tempering, asterism, laboratory, tempore,
# Nearest to other: advocates, timeline, menstrual, gollancz, containers, merits, cardinality, like,
# Nearest to after: bckgr, aba, position, anthropogenic, visual, recitative, execute, virtual,
# Nearest to only: eight, four, six, seven, zero, three, lymphoma, docked,
# Nearest to between: six, four, eight, three, seven, zero, nine, two,
# Nearest to there: that, this, it, and, agouti, vdc, also, what,
# Nearest to is: and, dictates, trumpets, inside, soviet, urgell, ssri, UNK,
# Nearest to the: their, the, its, her, s, agouti, dasyprocta, magistrate,
# Average loss at step  42000 :  5.341235838890076
# Average loss at step  44000 :  5.274800832271576
# Average loss at step  46000 :  5.203829362392425
# Average loss at step  48000 :  5.187050736427307
# Average loss at step  50000 :  5.1046797697544095
# Nearest to be: but, batting, lymphoma, moulds, vma, though, gundam, that,
# Nearest to five: a, battlefront, any, transferred, cyclists, that, haer, kapoor,
# Nearest to however: printers, kapoor, narrative, mukherjee, archie, digital, created, dependencies,
# Nearest to some: dasyprocta, operatorname, by, kapoor, is, circ, abet, sponsors,
# Nearest to new: tissue, these, agouti, out, archie, gigantopithecus, lemay, stockade,
# Nearest to often: four, six, five, seven, eight, two, zero, kapoor,
# Nearest to was: agouti, their, ursus, kapoor, its, this, a, dasyprocta,
# Nearest to b: agave, after, but, circ, and, aquaculture, for, two,
# Nearest to who: were, was, are, be, asterism, tempering, had, by,
# Nearest to other: advocates, timeline, gollancz, containers, menstrual, lott, merits, forbes,
# Nearest to after: bckgr, aba, position, visual, execute, virtual, anthropogenic, handler,
# Nearest to only: four, eight, six, lymphoma, docked, three, cruising, seven,
# Nearest to between: six, four, eight, three, seven, zero, nine, two,
# Nearest to there: that, this, agouti, and, what, it, also, vdc,
# Nearest to is: and, ursinus, hussars, dictates, trumpets, urgell, palestinian, ssri,
# Nearest to the: their, its, her, the, s, agouti, dasyprocta, record,
# Average loss at step  52000 :  5.100784014582634
# Average loss at step  54000 :  5.081681323051453
# Average loss at step  56000 :  5.095704735755921
# Average loss at step  58000 :  5.029109515786171
# Average loss at step  60000 :  5.018202128648758
# Nearest to be: but, lymphoma, batting, vma, though, that, moulds, operatorname,
# Nearest to five: any, battlefront, transferred, agouti, kapoor, this, ursus, haer,
# Nearest to however: printers, kapoor, narrative, mukherjee, archie, digital, complete, created,
# Nearest to some: circ, dasyprocta, operatorname, kapoor, in, abet, microcebus, abakan,
# Nearest to new: these, some, agouti, tissue, three, archie, two, gigantopithecus,
# Nearest to often: four, five, six, two, seven, eight, one, ursus,
# Nearest to was: agouti, their, kapoor, its, this, michelob, ursus, dasyprocta,
# Nearest to b: after, but, agave, circ, or, however, ursus, aquaculture,
# Nearest to who: was, be, were, by, tempering, had, asterism, tempore,
# Nearest to other: advocates, timeline, containers, merits, gollancz, lott, like, kapoor,
# Nearest to after: bckgr, aba, kapoor, cebus, cetacea, execute, position, visual,
# Nearest to only: four, five, six, eight, lymphoma, seven, three, docked,
# Nearest to between: four, six, eight, three, seven, nine, zero, two,
# Nearest to there: that, this, agouti, what, it, and, also, but,
# Nearest to is: and, hussars, ursinus, dictates, trumpets, urgell, palestinian, ssri,
# Nearest to the: their, its, her, the, s, agouti, dasyprocta, mico,
# Average loss at step  62000 :  4.904630549967289
# Average loss at step  64000 :  4.766067781090737
# Average loss at step  66000 :  4.761885208368302
# Average loss at step  68000 :  4.947946013092995
# Average loss at step  70000 :  4.862430568575859
# Nearest to be: but, though, batting, lymphoma, that, vma, moulds, while,
# Nearest to five: any, battlefront, a, haer, cyclists, transferred, kapoor, jogaila,
# Nearest to however: printers, digital, kapoor, dist, mukherjee, complete, narrative, envy,
# Nearest to some: operatorname, circ, dasyprocta, abakan, kapoor, abet, microcebus, is,
# Nearest to new: these, some, agouti, archie, tissue, amputation, many, ursus,
# Nearest to often: four, five, six, seven, eight, two, nine, zero,
# Nearest to was: their, agouti, this, its, kapoor, a, ursus, his,
# Nearest to b: but, after, agave, circ, however, and, or, when,
# Nearest to who: be, were, was, had, tempering, become, asterism, caicos,
# Nearest to other: advocates, merits, containers, timeline, like, gollancz, kapoor, cardinality,
# Nearest to after: bckgr, aba, cetacea, execute, virtual, visual, kapoor, position,
# Nearest to only: six, five, eight, four, seven, three, nine, lymphoma,
# Nearest to between: four, six, three, eight, seven, zero, nine, two,
# Nearest to there: that, this, what, agouti, it, also, but, kapoor,
# Nearest to is: hussars, and, ursinus, trumpets, dictates, urgell, palestinian, UNK,
# Nearest to the: their, her, its, the, s, agouti, dasyprocta, mico,
# Average loss at step  72000 :  4.752057863116264
# Average loss at step  74000 :  4.816267738342285
# Average loss at step  76000 :  4.756816507101059
# Average loss at step  78000 :  4.78315535056591
# Average loss at step  80000 :  4.787285134792328
# Nearest to be: but, though, that, batting, lymphoma, while, operatorname, vma,
# Nearest to five: any, busan, battlefront, ursus, agouti, a, kapoor, this,
# Nearest to however: printers, digital, kapoor, mukherjee, complete, narrative, dist, envy,
# Nearest to some: operatorname, circ, dasyprocta, abakan, kapoor, microcebus, busan, abet,
# Nearest to new: these, some, agouti, two, many, archie, out, amputation,
# Nearest to often: four, five, six, two, seven, eight, agouti, ursus,
# Nearest to was: agouti, their, its, kapoor, michelob, ursus, dasyprocta, a,
# Nearest to b: but, after, agave, circ, however, when, fachhochschule, or,
# Nearest to who: be, was, were, become, had, by, tempering, asterism,
# Nearest to other: merits, advocates, containers, timeline, kapoor, gollancz, like, cardinality,
# Nearest to after: bckgr, cetacea, aba, lamenting, execute, virtual, handler, visual,
# Nearest to only: five, six, seven, lymphoma, four, cruising, docked, eight,
# Nearest to between: four, six, seven, eight, three, two, zero, nine,
# Nearest to there: that, this, what, agouti, it, also, but, kapoor,
# Nearest to is: hussars, and, kapoor, supplies, trumpets, ursinus, kifl, dictates,
# Nearest to the: their, her, its, the, s, agouti, mico, dasyprocta,
# Average loss at step  82000 :  4.769609007239342
# Average loss at step  84000 :  4.794765340924263
# Average loss at step  86000 :  4.739687342643737
# Average loss at step  88000 :  4.779826675772667
# Average loss at step  90000 :  4.697351190209389
# Nearest to be: but, though, that, batting, while, lymphoma, operatorname, moulds,
# Nearest to five: any, a, busan, battlefront, this, ursus, agouti, haer,
# Nearest to however: printers, kapoor, digital, mukherjee, erasable, dist, complete, narrative,
# Nearest to some: operatorname, circ, kapoor, dasyprocta, by, abet, rasterization, when,
# Nearest to new: these, some, agouti, many, archie, ursus, amputation, dasyprocta,
# Nearest to often: four, two, five, seven, six, eight, nine, one,
# Nearest to was: their, its, agouti, kapoor, a, this, his, ursus,
# Nearest to b: but, after, however, when, agave, although, circ, and,
# Nearest to who: be, was, were, become, by, had, tempering, asterism,
# Nearest to other: merits, timeline, advocates, containers, kapoor, gollancz, cardinality, lott,
# Nearest to after: bckgr, cetacea, aba, lamenting, execute, virtual, handler, visual,
# Nearest to only: eight, five, seven, six, nine, four, docked, lymphoma,
# Nearest to between: seven, four, eight, six, three, nine, zero, two,
# Nearest to there: that, this, what, but, it, also, agouti, and,
# Nearest to is: UNK, and, hussars, supplies, kapoor, trumpets, urgell, kifl,
# Nearest to the: their, her, its, the, s, agouti, curlers, dasyprocta,
# Average loss at step  92000 :  4.703354943275452
# Average loss at step  94000 :  4.688486014246941
# Average loss at step  96000 :  4.653925635814667
# Average loss at step  98000 :  4.649990322828293
